# %%
#initilaization
import math
type = input("Type: ")
type.lower()
mag = 0
angle = 0
comp = 0+0j
type_b = False

if type == "phasor" or type == "p":
    mag = float(input("Magnitude: "))
    angle = float(input("angle (Degrees): "))
    type_b = True
elif type == "complex" or type == "c":
    comp = complex(input("complex: "))
    type_b = False
else:
    print("invalid type")

if not (all(isinstance(var, (int, float)) for var in (mag, angle)) or isinstance(comp, complex)):
    print("invalid input")

# %%
#Conversion phasor -> complex
def convertPC(type_b, mag, ):
    if type_b: 
        angle_radian = math.radians(angle)
        comp_out = math.cos(angle_radian) + math.sin(angle_radian)*1j
        print(comp_out)
    elif not type_b:
        real = comp.real
        imag = comp.imag

        mag_out = math.sqrt(real ** 2 + imag ** 2)
        radian_out = math.atan(imag/real)
        angle_out = math.degrees(radian_out)

        print(str(mag_out) + "<" + str(angle_out))

convert(type_b)
# Out:
# 1.4142135623730951<45.0

# %%
Testing testing
